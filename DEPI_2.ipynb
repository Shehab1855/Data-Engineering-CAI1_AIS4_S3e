# %%
import pyodbc
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler ,StandardScaler 
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import joblib

# %%
from sqlalchemy import create_engine

# 1. Connection string (change this line if needed)
connection_string = "mssql+pyodbc://@ABDELRAHMAN\SQLEXPRESS/Dataset?driver=ODBC+Driver+17+for+SQL+Server&trusted_connection=yes"

# Create the SQLAlchemy engine
engine = create_engine(connection_string)

# 2. Query to get all table names from the database (no changes needed)
table_query = """
SELECT TABLE_NAME 
FROM INFORMATION_SCHEMA.TABLES 
WHERE TABLE_TYPE = 'BASE TABLE'
"""
# Load the list of tables into a DataFrame (no changes needed)
table_names = pd.read_sql(table_query, engine)

# Iterate over the table names and load each table into a DataFrame
dataframes = {}  # Dictionary to hold DataFrames for each table
for table in table_names['TABLE_NAME']:
    print(f"Loading data from table: {table}")
    
    # 3. SQL query to load all data from the current table (no changes needed)
    query = f"SELECT * FROM [{table}]"
    
    # Load the entire table into a pandas DataFrame
    df = pd.read_sql(query, engine)
    
    # Store the DataFrame in the dictionary with the table name as the key
    dataframes[table] = df

    # Print the first few rows of each table as they are loaded (no changes needed)
    df.head()

# 4. Access data from a specific table (if needed, modify the table name here)
tables = dataframes['customers']  # Replace 'SomeTableName' with your actual table name
tables
# Out:
# Loading data from table: customers
# Loading data from table: locations
# Loading data from table: merchants
# Loading data from table: OLE DB Destination
# Loading data from table: transactions
#           ID            cc_num    first      last gender  \
# 0          0  2291160000000000     Jeff   Elliott      M
# 1          1  3573030000000000   Joanne  Williams      F
# 2          2  3598220000000000   Ashley     Lopez      F
# 3          3  3591920000000000    Brian  Williams      M
# 4          4  3526830000000000   Nathan    Massey      M
# ...      ...               ...      ...       ...    ...
# 99994  99994   371034000000000   Jeremy     Jones      M
# 99995  99995  2242540000000000   Samuel   Jenkins      M
# 99996  99996  4482430000000000   Leslie      Ford      F
# 99997  99997  5580560000000000  Stanley   Dickson      M
# 99998  99998  4294040000000000     Gail    Weaver      F
#
#                                 dob                         street  \
# ...

# %%
tables = dataframes['locations'] 
tables
# Out:
#           ID    zip          city state    lat    long  city_pop
# 0          0  29209      Columbia    SC  33.97  -80.94    333497
# 1          1  84002       Altonah    UT  40.32 -110.44       302
# 2          2  11710      Bellmore    NY  40.67  -73.54     34496
# 3          3  32780    Titusville    FL  28.57  -80.82     54767
# 4          4  49632      Falmouth    MI  44.25  -85.02      1126
# ...      ...    ...           ...   ...    ...     ...       ...
# 99994  99994  96135        Vinton    CA  40.02 -120.80       128
# 99995  99995  40077      Westport    KY  38.49  -85.45       564
# 99996  99996  25106     Henderson    WV  38.83  -82.14       642
# 99997  99997  15480         Smock    PA  40.00  -79.77      1946
# 99998  99998  29809  New Ellenton    SC  33.41  -81.69      2206
#
# [99999 rows x 7 columns]

# %%
tabels = dataframes['merchants']  
tabels

# %%
tabels = dataframes['OLE DB Destination'] 
tabels

# %%
tabels = dataframes['transactions']  
tabels
